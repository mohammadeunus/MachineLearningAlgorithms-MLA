# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadeunus/MachineLearningAlgorithms-MLA/blob/main/07_hmm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hmm = (transition*emission)\prior![image.png](data:image/png;base64,...)

# %%
def calculatePobability(Day1, Day2, Day3, umbrella2, umbrella3,):
  priorProbabiliity =0.5
  #transion and emition probability
  emission = [[0.6, 0.3, 0.1],
           [0.1, 0.7, 0.2],
           [0.2, 0.3, 0.5]]
  
  transition = [[0.9,  0.05, 0.05],
              [0.05, 0.9, 0.05],
              [0.05, 0.05, 0.9]]

  return (emission[Day1][Day2] * emission[Day1][Day2] * transition[Day2][Day3] * transition[Day2][Day3])/ (0.5* 0.5)
  



if __name__ == "__main__":
  #declaring the answer integer
  Ans =0

  # sunny=0 rainy=1 foggy=2
  #first day
  weather1=0
  #second day   USER INPUT
  umbrella2=1
  #third day
  weather3=2
  umbrella3=0
  #prior probabiliity
  priorProbabiliity=0.5
  
  #weather1-weather2-weather3
  for weather2 in range(3):
    Ans+= calculatePobability(weather1,weather2,weather3,umbrella2,umbrella3)
  
  print(Ans)
# Out:
# 0.03690000000000001
